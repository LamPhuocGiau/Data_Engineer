# %% [markdown]
# Exercise 5: View in subplots

# %% [markdown]
# #### Setup

# %%
# import matplotlib and pandas
from matplotlib import pyplot as plt
import pandas as pd

# load dataset
scatter_data = pd.read_csv('spotify_data_by_genres.csv')
scatter_data.head()
# Out:
#    mode                  genres  acousticness  danceability   duration_ms  \
# 0     1  21st century classical      0.979333      0.162883  1.602977e+05
# 1     1                   432hz      0.494780      0.299333  1.048887e+06
# 2     1                   8-bit      0.762000      0.712000  1.151770e+05
# 3     1                      []      0.651417      0.529093  2.328809e+05
# 4     1              a cappella      0.676557      0.538961  1.906285e+05
#
#      energy  instrumentalness  liveness   loudness  speechiness       tempo  \
# 0  0.071317          0.606834  0.361600 -31.514333     0.040567   75.336500
# 1  0.450678          0.477762  0.131000 -16.854000     0.076817  120.285667
# 2  0.818000          0.876000  0.126000  -9.180000     0.047000  133.444000
# 3  0.419146          0.205309  0.218696 -12.288965     0.107872  112.857352
# 4  0.316434          0.003003  0.172254 -12.479387     0.082851  112.110362
#
#     valence  popularity  key
# 0  0.103783   27.833333    6
# ...

# %%
# display charts correctly
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['figure.dpi'] = 75

# %% [markdown]
# 1. First, run the Setup cells above to load in the necessary packages and the `spotify_data_by_genres` csv. **Our goal for this exercise is to see if any of the variables have a correlation with the `popularity` variable.** In the cell below, write the code to make a subplot grid with 3 rows and 4 columns. We won't put any graphs in the grid yet, so your code will use only the `subplot` function.

# %%
## YOUR SOLUTION HERE ##
plt.subplot(3,4,1)
plt.subplot(3,4,2)
plt.subplot(3,4,3)
plt.subplot(3,4,4)
plt.subplot(3,4,5)
plt.subplot(3,4,6)
plt.subplot(3,4,7)
plt.subplot(3,4,8)
plt.subplot(3,4,9)
plt.subplot(3,4,10)
plt.subplot(3,4,11)
plt.subplot(3,4,12)
plt.show()

# %% [markdown]
# 2. Now, add a line of code below each subplot to make a scatterplot in each square of the grid. Each scatterplot should have `popularity` as the x-variable and then the following y-variables: `acousticness`, `danceability`, `duration_ms`, `energy`, `instrumentalness`, `liveness`, `loudness`, `speechiness`, `tempo`, `valence`, `key`, and `popularity`. (Yes, the final square will plot `popularity` against itself!) Set the `alpha` equal to `0.05`.

# %%
## YOUR SOLUTION HERE ##
plt.subplot(3,4,1)
plt.scatter(scatter_data.popularity, scatter_data.acousticness, alpha=0.05)
plt.subplot(3,4,2)
plt.scatter(scatter_data.popularity, scatter_data.danceability, alpha=0.05)
plt.subplot(3,4,3)
plt.scatter(scatter_data.popularity, scatter_data.duration_ms, alpha=0.05)
plt.subplot(3,4,4)
plt.scatter(scatter_data.popularity, scatter_data.energy, alpha=0.05)
plt.subplot(3,4,5)
plt.scatter(scatter_data.popularity, scatter_data.instrumentalness, alpha=0.05)
plt.subplot(3,4,6)
plt.scatter(scatter_data.popularity, scatter_data.liveness, alpha=0.05)
plt.subplot(3,4,7)
plt.scatter(scatter_data.popularity, scatter_data.loudness, alpha=0.05)
plt.subplot(3,4,8)
plt.scatter(scatter_data.popularity, scatter_data.speechiness, alpha=0.05)
plt.subplot(3,4,9)
plt.scatter(scatter_data.popularity, scatter_data.tempo, alpha=0.05)
plt.subplot(3,4,10)
plt.scatter(scatter_data.popularity, scatter_data.valence, alpha=0.05)
plt.subplot(3,4,11)
plt.scatter(scatter_data.popularity, scatter_data.key, alpha=0.05)
plt.subplot(3,4,12)
plt.scatter(scatter_data.popularity, scatter_data.popularity, alpha=0.05)
plt.show()

# %% [markdown]
# 3. This gives us something to work with! These correlations are a bit all over the place, and  the ability to easily compare their differences is helpful. **Add a title above each graph using and instance of `plt.title()` for each subplot.**

# %%
## YOUR SOLUTION HERE ##
plt.subplot(3,4,1)
plt.scatter(scatter_data.popularity, scatter_data.acousticness, alpha=0.05)
plt.title('acousticness')
plt.subplot(3,4,2)
plt.scatter(scatter_data.popularity, scatter_data.danceability, alpha=0.05)
plt.title('danceability')
plt.subplot(3,4,3)
plt.scatter(scatter_data.popularity, scatter_data.duration_ms, alpha=0.05)
plt.title('duration_ms')
plt.subplot(3,4,4)
plt.scatter(scatter_data.popularity, scatter_data.energy, alpha=0.05)
plt.title('energy')
plt.subplot(3,4,5)
plt.scatter(scatter_data.popularity, scatter_data.instrumentalness, alpha=0.05)
plt.title('instrumentalness')
plt.subplot(3,4,6)
plt.scatter(scatter_data.popularity, scatter_data.liveness, alpha=0.05)
plt.title('liveness')
plt.subplot(3,4,7)
plt.scatter(scatter_data.popularity, scatter_data.loudness, alpha=0.05)
plt.title('loudness')
plt.subplot(3,4,8)
plt.scatter(scatter_data.popularity, scatter_data.speechiness, alpha=0.05)
plt.title('speechiness')
plt.subplot(3,4,9)
plt.scatter(scatter_data.popularity, scatter_data.tempo, alpha=0.05)
plt.title('tempo')
plt.subplot(3,4,10)
plt.scatter(scatter_data.popularity, scatter_data.valence, alpha=0.05)
plt.title('valence')
plt.subplot(3,4,11)
plt.scatter(scatter_data.popularity, scatter_data.key, alpha=0.05)
plt.title('key')
plt.subplot(3,4,12)
plt.scatter(scatter_data.popularity, scatter_data.popularity, alpha=0.05)
plt.title('popularity')
plt.subplots_adjust(hspace=0.5, wspace=0.3)
plt.show()

# %% [markdown]
# 4. Finally, we'll add our super title. Above the first subplot, add a line of code to make the super title: 'Relationship between Popularity and _______________'.

# %%
## YOUR SOLUTION HERE ##
plt.suptitle('Relationship between Popularity and ______')
plt.subplot(3,4,1)
plt.scatter(scatter_data.popularity, scatter_data.acousticness, alpha=0.05)
plt.title('acousticness')
plt.subplot(3,4,2)
plt.scatter(scatter_data.popularity, scatter_data.danceability, alpha=0.05)
plt.title('danceability')
plt.subplot(3,4,3)
plt.scatter(scatter_data.popularity, scatter_data.duration_ms, alpha=0.05)
plt.title('duration_ms')
plt.subplot(3,4,4)
plt.scatter(scatter_data.popularity, scatter_data.energy, alpha=0.05)
plt.title('energy')
plt.subplot(3,4,5)
plt.scatter(scatter_data.popularity, scatter_data.instrumentalness, alpha=0.05)
plt.title('instrumentalness')
plt.subplot(3,4,6)
plt.scatter(scatter_data.popularity, scatter_data.liveness, alpha=0.05)
plt.title('liveness')
plt.subplot(3,4,7)
plt.scatter(scatter_data.popularity, scatter_data.loudness, alpha=0.05)
plt.title('loudness')
plt.subplot(3,4,8)
plt.scatter(scatter_data.popularity, scatter_data.speechiness, alpha=0.05)
plt.title('speechiness')
plt.subplot(3,4,9)
plt.scatter(scatter_data.popularity, scatter_data.tempo, alpha=0.05)
plt.title('tempo')
plt.subplot(3,4,10)
plt.scatter(scatter_data.popularity, scatter_data.valence, alpha=0.05)
plt.title('valence')
plt.subplot(3,4,11)
plt.scatter(scatter_data.popularity, scatter_data.key, alpha=0.05)
plt.title('key')
plt.subplot(3,4,12)
plt.scatter(scatter_data.popularity, scatter_data.popularity, alpha=0.05)
plt.title('popularity')
plt.subplots_adjust(hspace=0.5, wspace=0.3)
plt.show()

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>So, what's the relationship?</i></summary>
#
# Truthfully, none of these are strong correlations. But sometimes it's important to be able to see and communicate **that** clearly. This Spotify dataset is enormous and unwieldy, and this format helps us cut through the noise quickly and clearly. <br><br>Also, while there isn't evidence of a simple correlation between two variables, the similarities between variables like `danceability`, `valence`, and `energy` suggest that those combinations might yield a stronger pattern if we investigate them next. There's also a lot of information here about variance (how spread out or clustered the data is) and extremes (the bounds and outliers of the data). So, well worth the work, even if it didn't provide an 'aha' moment for the original goal!</summary>

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>Can we make these charts with less code?</i></summary>
#
# If this looks like a lot of code for charts, that's because it *is* a fair amount! Also notice that a lot of the code is the same in each line, with just one key piece of information altered. This is a perfect candidate for a `for` loop, which will make charts programmatically in just a couple lines of code. That's outside the scope of this course, but a good thing to know about for those who plan to make a lot of charts and subplots!</summary>
